# %%
'''
yfinance pacakge
'''
# !pip install yfinance

# %%
'''
boto3 pacakge
'''
# !pip install boto3

# %%
# Libraries
import pandas as pd
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import sqlite3
import boto3
from botocore.exceptions import NoCredentialsError

# %%
stocks = ['AAPL', 'MSFT', 'GOOGL', 'TSLA', 'AMZN']

# %%
# General Info
# Initialize an empty list to store the data
data = []

# Iterate through the list of stock symbols
for symbol in stocks:
    stock = yf.Ticker(symbol)
    stock_info = stock.info
    print(stock.info)
    url = f'https://finance.yahoo.com/quote/{symbol}?p={symbol}&.tsrc=fin-srch'
    response = requests.get(url)
    if response.status_code == 200:
        stock_info = {
            'ticker': symbol,
            'website': stock_info["website"],
            'industry': stock_info["industry"],
            #'longBusinessSummary': stock_info["longBusinessSummary"],
        }
        data.append({
            'Ticker': stock_info['ticker'],
            'Website': stock_info['website'],
            'Industry': stock_info['industry'],
            #'Description': stock_info['longBusinessSummary'],
        })
        industryDisp
        sector
# Out:
# {'address1': 'One Apple Park Way', 'city': 'Cupertino', 'state': 'CA', 'zip': '95014', 'country': 'United States', 'phone': '408 996 1010', 'website': 'https://www.apple.com', 'industry': 'Consumer Electronics', 'industryKey': 'consumer-electronics', 'industryDisp': 'Consumer Electronics', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In a
# ...

# %%
stock_info
# Out:
# {'ticker': 'AMZN',
#  'website': 'https://www.aboutamazon.com',
#  'industry': 'Internet Retail'}

# %%
# Create a DataFrame from the collected data
info_df = pd.DataFrame(data)
print(info_df)
# Out:
#   Ticker                      Website                        Industry
# 0   AAPL        https://www.apple.com            Consumer Electronics
# 1   MSFT    https://www.microsoft.com       Software - Infrastructure
# 2  GOOGL          https://www.abc.xyz  Internet Content & Information
# 3   TSLA        https://www.tesla.com              Auto Manufacturers
# 4   AMZN  https://www.aboutamazon.com                 Internet Retail

# %%
# companyOfficers
company_dataframes = []

# Iterate through the list of stock symbols
for symbol in stocks:
    stock = yf.Ticker(symbol)
    stock_info = stock.info

    # Check if "companyOfficers" information is available
    if 'companyOfficers' in stock_info:
        officers_data = []
        for i in range(len(stock_info['companyOfficers'])):
            officers_data.append({
                'Name': stock_info['companyOfficers'][i]['name'],
                'Title': stock_info['companyOfficers'][i]['title']
            })
        officers_df = pd.DataFrame(officers_data)
        company_dataframes.append(officers_df)

company_dict = {symbol: df for symbol, df in zip(stocks, company_dataframes)}

# %%
# Access DataFrames for individual companies
for symbol, df in company_dict.items():
    print(f"Company: {symbol}")
    print(df)
# Out:
# Company: AAPL
#                       Name                                             Title
# 0      Mr. Timothy D. Cook                                    CEO & Director
# 1        Mr. Luca  Maestri                                   CFO & Senior VP
# 2  Mr. Jeffrey E. Williams                           Chief Operating Officer
# 3   Ms. Katherine L. Adams            Senior VP, General Counsel & Secretary
# 4     Ms. Deirdre  O'Brien                   Senior Vice President of Retail
# 5         Mr. Chris  Kondo           Senior Director of Corporate Accounting
# 6        Mr. James  Wilson                          Chief Technology Officer
# 7          Ms. Mary  Demby                         Chief Information Officer
# 8        Ms. Nancy  Paxton  Senior Director of Investor Relations & Treasury
# 9        Mr. Greg  Joswiak      Senior Vice President of Worldwide Marketing
# Company: MSFT
#                           Name  \
# 0           Mr. Satya  Nadella
# ...

# %%
# news links
# Create a list of DataFrames, one for each company
news_dataframes = []

# Iterate through the list of stock symbols
for symbol in stocks:
    stock = yf.Ticker(symbol)
    stock_info = stock.info
    news_data = stock.news
    news_data_filtered = [{'uuid': news['uuid'], 'link': news['link']} for news in news_data]

    if news_data_filtered:
        news_df = pd.DataFrame(news_data_filtered)
        news_dataframes.append(news_df)

# Create a dictionary to store DataFrames with company symbol as key
news_dict = {symbol: df for symbol, df in zip(stocks, news_dataframes)}

# Access DataFrames for individual companies
for symbol, news_df in news_dict.items():
    #print(f"Company: {symbol}")
    print(news_df)
# Out:
#                                    uuid  \
# 0  1d5cb413-7e45-3efa-bbde-7f5b1eddd3c5
# 1  649cada5-a540-3629-806b-0f7c23ad1d20
# 2  2e68d3ca-4548-3e13-824c-b942146c8867
# 3  f96b3a40-f8e8-379e-bf2e-5e1342db508d
# 4  ce9d1476-08b4-35ba-aa8f-837bd7a32cf5
# 5  fa16bc22-d6b9-3360-afc4-667d543ac1b9
# 6  08960913-4bd1-3168-8f1f-a40bb754ec14
# 7  bb017c59-7a25-39fe-8608-84c2619d2b43
#
#                                                 link
# 0  https://finance.yahoo.com/m/1d5cb413-7e45-3efa...
# 1  https://finance.yahoo.com/news/google-antitrus...
# 2  https://finance.yahoo.com/news/apple-inc-nasda...
# 3  https://finance.yahoo.com/m/f96b3a40-f8e8-379e...
# 4  https://finance.yahoo.com/news/little-bit-worr...
# 5  https://finance.yahoo.com/m/fa16bc22-d6b9-3360...
# 6  https://finance.yahoo.com/m/08960913-4bd1-3168...
# 7  https://finance.yahoo.com/m/bb017c59-7a25-39fe...
#                                    uuid  \
# 0  a88944da-d971-3ad3-a15b-e177775da437
# ...

# %%
type(info_df)
#type(company_dict)
#type(news_dict)
# Out:
# pandas.core.frame.DataFrame

# %%
# download
#CSV
news_df.to_csv('news_df.csv', index=False)

# %%
# txt
news_df.to_csv('news_df.txt', sep='\t', index=False)

# %%
# json
import json
news_df.to_json('news_df.json', orient='records')

# %%
range_52w = stock.info.get("dayRange")
print(f"52W Range: {range_52w}")

# Get the 52-week high
high_52w = stock.info.get("dayHigh")
print(f"52W High: {high_52w}")

# Get the 52-week low
low_52w = stock.info.get("dayLow")
print(f"52W Low: {low_52w}")

# Get the market capitalization
market_cap = stock.info.get("marketCap")
print(f"Market Cap: {market_cap}")

# Get the shares outstanding
shares_outstanding = stock.info.get("sharesOutstanding")
print(f"Shares Outstanding: {shares_outstanding}")

# Get the public float
public_float = stock.info.get("floatShares")
print(f"Public Float: {public_float}")



pe_ratio = stock.info.get("trailingPE")
print(f"P/E Ratio: {pe_ratio}")

# Get the Earnings Per Share (EPS)
eps = stock.info.get("trailingEps")
print(f"EPS: {eps}")

# Get the Dividend yield (annual)
dividend_yield = stock.info.get("dividendYield")
print(f"Dividend %: {dividend_yield * 100:.2f}%")

# Get the Annual Dividend Per Share
dividend = stock.info.get("trailingAnnualDividendRate")
print(f"Dividend: {dividend}")

# Get the Ex-dividend date
ex_dividend_date = stock.info.get("exDividendDate")
print(f"Ex-dividend Date: {ex_dividend_date}")

# Get the Short float (%)
short_float_percent = stock.info.get("sharesShort") / stock.info.get("sharesOutstanding")
print(f"Short Float: {short_float_percent * 100:.2f}%")

income = stock.info.get("trailingAnnualNetIncome")
print(f"Income: {income}")

# Get the Revenue (ttm)
revenue = stock.info.get("trailingAnnualRevenue")
print(f"Sales (Revenue): {revenue}")

# Get the Book value per share (mrq)
book_value_per_share = stock.info.get("bookValue")
print(f"Book/sh: {book_value_per_share}")

# Get the Cash per share (mrq)
cash_per_share = stock.info.get("trailingAnnualCashFlow")
print(f"Cash/sh: {cash_per_share}")

# Check if the stock is optionable
optionable = stock.info.get("options")
print(f"Optionable: {optionable}")

# Get the number of full-time employees
employees = stock.info.get("fullTimeEmployees")
print(f"Employees: {employees}")

# Check if the stock is shortable
shortable = stock.info.get("sharesShort")
print(f"Shortable: {shortable}")
# Out:
# 52W Range: None
# 52W High: 259.5947
# 52W Low: 250.22
# Market Cap: 797052305408
# Shares Outstanding: 3173989888
# Public Float: 2713574830
# P/E Ratio: 71.34091
# EPS: 3.52
# Dividend %: 1.83%
# Dividend: 0.0
# Ex-dividend Date: None
# Short Float: 2.60%

# %%
stock.info.get("recommendationMean")
ps_ratio = stock.info.get("priceToSalesTrailing12Months")
print(f"P/S Ratio: {ps_ratio}")

# Get the Price-to-Book (P/B) ratio
pb_ratio = stock.info.get("priceToBook")
print(f"P/B Ratio: {pb_ratio}")

# Get the Price-to-Cash per Share (P/C)
pc_ratio = stock.info.get("priceToCashPerShare")
print(f"P/C Ratio: {pc_ratio}")

# Get the Price-to-Free Cash Flow (P/FCF) ratio
pfcf_ratio = stock.info.get("priceToFreeCashFlows")
print(f"P/FCF Ratio: {pfcf_ratio}")

# Get the Quick Ratio
quick_ratio = stock.info.get("quickRatio")
print(f"Quick Ratio: {quick_ratio}")

# Get the Current Ratio
current_ratio = stock.info.get("currentRatio")
print(f"Current Ratio: {current_ratio}")

# Get the Total Debt to Equity (Debt/Equity) ratio
debt_to_equity = stock.info.get("debtToEquity")
print(f"Debt/Equity Ratio: {debt_to_equity}")

# Get the Long Term Debt to Equity (LT Debt/Equity) ratio
lt_debt_to_equity = stock.info.get("longTermDebtToEquity")
print(f"LT Debt/Equity Ratio: {lt_debt_to_equity}")

# Get the Distance from the 20-Day Simple Moving Average (SMA 20)
sma_20 = stock.info.get("fiftyDayAverage")  # Note that 50-day average is similar to 20-day
print(f"Distance from 20-Day SMA: {sma_20}")

# Get the Distance from the 50-Day Simple Moving Average (SMA 50)
sma_50 = stock.info.get("twoHundredDayAverage")  # Note that 200-day average is similar to 50-day
print(f"Distance from 50-Day SMA: {sma_50}")

# Get the Distance from the 200-Day Simple Moving Average (SMA 200)
sma_200 = stock.info.get("twoHundredDayAverage")
print(f"Distance from 200-Day SMA: {sma_200}")
# Out:
# 2.7

# %%
eps_ttm = stock.info.get("trailingEps")
print(f"EPS (ttm): {eps_ttm}")

# Get the EPS estimate for next year (EPS next Y)
eps_next_year = stock.info.get("forwardEps")
print(f"EPS next Y: {eps_next_year}")

# Get the EPS estimate for the next quarter (EPS next Q)
eps_next_quarter = stock.info.get("epsEstimateNextQuarter")
print(f"EPS next Q: {eps_next_quarter}")

# Get the EPS estimate for this year (EPS this Y)
eps_this_year = stock.info.get("forwardPE")
print(f"EPS this Y: {eps_this_year}")

# Get the EPS growth for this year
eps_growth_this_year = stock.info.get("earningsQuarterlyGrowth")
print(f"EPS Growth This Year: {eps_growth_this_year}")

# Get the EPS estimate for the next year (EPS next Y)
eps_next_year_2 = stock.info.get("forwardPE")
print(f"EPS next Y: {eps_next_year_2}")

# Get the long-term annual growth estimate for the next 5 years (EPS next 5Y)
eps_next_5_years = stock.info.get("fiveYearAvgGrowth")
print(f"EPS next 5Y: {eps_next_5_years}")

# Get the annual EPS growth for the past 5 years (EPS past 5Y)
eps_past_5_years = stock.info.get("trailingEps")
print(f"EPS past 5Y: {eps_past_5_years}")

# Get the annual sales growth for the past 5 years (Sales past 5Y)
sales_past_5_years = stock.info.get("trailingEps")
print(f"Sales past 5Y: {sales_past_5_years}")

# Get the quarterly revenue growth (YoY) (Sales Q/Q)
sales_qq = stock.info.get("earningsQuarterlyGrowth")
print(f"Sales Q/Q: {sales_qq}")

# Get the quarterly earnings growth (YoY) (EPS Q/Q)
eps_qq = stock.info.get("earningsQuarterlyGrowth")
print(f"EPS Q/Q: {eps_qq}")


aapl = stock

# Get Insider Ownership (Insider Own)
insider_own = aapl.info.get("percentInsiders")
print(f"Insider Own: {insider_own * 100:.2f}%")

# Get Institutional Ownership (Inst Own)
inst_own = aapl.info.get("percentInstitutions")
print(f"Inst Own: {inst_own * 100:.2f}%")

# Get Return on Assets (ROA)
roa = aapl.info.get("returnOnAssets")
print(f"ROA: {roa * 100:.2f}%")

# Get Return on Equity (ROE)
roe = aapl.info.get("returnOnEquity")
print(f"ROE: {roe * 100:.2f}%")

# Get Net Profit Margin (Profit Margin)
profit_margin = aapl.info.get("profitMargins")
print(f"Profit Margin: {profit_margin * 100:.2f}%")

# Get Dividend Payout Ratio (Payout)
payout_ratio = aapl.info.get("payoutRatio")
print(f"Payout: {payout_ratio * 100:.2f}%")

# Get Shares Outstanding (Shs Outstand)
shares_outstanding = aapl.info.get("sharesOutstanding")
print(f"Shs Outstand: {shares_outstanding}")

# Get Shares Float (Shs Float)
shares_float = aapl.info.get("floatShares")
print(f"Shs Float: {shares_float}")

# Get Short Interest (Short Interest)
short_interest = aapl.info.get("sharesShort")
print(f"Short Interest: {short_interest}")

# Get Relative Strength Index (RSI) for 14 days (RSI (14))
rsi_14 = aapl.info.get("relativeStrengthIndex")
print(f"RSI (14): {rsi_14}")

# Get Beta (Beta)
beta = aapl.info.get("beta")
print(f"Beta: {beta}")

# Get Average True Range (ATR)
atr = aapl.info.get("averageTrueRange")
print(f"ATR: {atr}")

# Get Previous Close (Prev Close)
prev_close = aapl.info.get("regularMarketPreviousClose")
print(f"Prev Close: {prev_close}")

# Get Current Stock Price (Price)
current_price = aapl.info.get("last_price")
print(f"Price: {current_price}")

# Get Performance (Today) (Change)
change_today = aapl.info.get("regularMarketChange")
print(f"Change (Today): {change_today}")

# Get Book Value
book_value = aapl.info.get("bookValue")
print(f"Book Value: {book_value}")

# Get Long Term Debt to Equity (LT Debt/Equity)
lt_debt_equity = aapl.info.get("debtToEquity")
print(f"LT Debt/Equity: {lt_debt_equity}")

# Get Analysts' Mean Target Price (Target Price)
target_price = aapl.info.get("targetMeanPrice")
print(f"Target Price: {target_price}")

# %%
# Income statements
total_revenue = stock.info.get("revenue")
cost_of_goods_sold = stock.info.get("costOfRevenue")
gross_profit = stock.info.get("grossProfit")
sga_excluding_other = stock.info.get("sellingGeneralAndAdmin")
other_operating_expense = stock.info.get("otherOperatingExpenses")
operating_income = stock.info.get("operatingIncome")
interest_expense = stock.info.get("interestExpense")
unusual_expense = stock.info.get("unusualExpenses")
net_income_before_taxes = stock.info.get("incomeBeforeTax")
income_taxes = stock.info.get("taxProvision")
consolidated_net_income = stock.info.get("netIncome")
net_income_from_continuing_operations = stock.info.get("netIncomeFromContinuingOps")
net_income = stock.info.get("netIncomeApplicableToCommon")
eps_recurring = stock.info.get("trailingEps")
eps_basic = stock.info.get("trailingPE")
eps_diluted = stock.info.get("dilutedEps")
ebitda = stock.info.get("ebitda")

# Get price-related metrics
pe_ratio = stock.info.get("trailingPE")
ps_ratio = stock.info.get("priceToSalesTrailing12Months")

# Get margin-related metrics
gross_margin = (stock.info.get("grossProfit") / stock.info.get("revenue")) * 100
operating_margin = (stock.info.get("operatingIncome") / stock.info.get("revenue")) * 100
net_margin = (stock.info.get("netIncome") / stock.info.get("revenue")) * 100

# Get other metrics
shares_outstanding = stock.info.get("sharesOutstanding")
market_cap = stock.info.get("marketCap")

# %%
# Get financial metrics
total_assets = stock.info.get("totalAssets")
current_assets = stock.info.get("totalCurrentAssets")
cash_and_short_term_investments = stock.info.get("cashAndShortTermInvestments")
cash_equivalents = stock.info.get("cashEquiv")
other_short_term_investments = stock.info.get("otherShortTermInvestments")
receivables = stock.info.get("netReceivables")
accounts_receivable = stock.info.get("netReceivables")
inventory = stock.info.get("inventory")
raw_materials = stock.info.get("rawMaterials")
work_in_process = stock.info.get("workInProcess")
finished_goods = stock.info.get("finishedGoods")
other_inventories = stock.info.get("otherInventories")
prepaid_assets = stock.info.get("prepaidExpenses")
restricted_cash = stock.info.get("restrictedCash")
other_current_assets = stock.info.get("otherCurrentAssets")
total_non_current_assets = stock.info.get("totalNonCurrentAssets")
net_ppe = stock.info.get("netPropertyPlantEquipment")
gross_ppe = stock.info.get("grossPropertyPlantEquipment")
properties = stock.info.get("propertyPlantEquipment")
land_and_improvements = stock.info.get("landAndImprovements")
machinery_furniture_equipment = stock.info.get("machineryFurnitureEquipment")
other_properties = stock.info.get("otherProperties")
construction_in_progress = stock.info.get("constructionInProgress")
leases = stock.info.get("capitalLeaseObligations")
accumulated_depreciation = stock.info.get("accumulatedDepreciation")
goodwill_and_intangible_assets = stock.info.get("goodwillAndIntangibleAssets")
goodwill = stock.info.get("goodwill")
other_intangible_assets = stock.info.get("otherIntangibleAssets")
non_current_note_receivables = stock.info.get("nonCurrentNoteReceivables")
other_non_current_assets = stock.info.get("otherNonCurrentAssets")

# Get liability metrics
total_liabilities_net_minority_interest = stock.info.get("totalLiabilitiesNetMinorityInterest")
current_liabilities = stock.info.get("totalCurrentLiabilities")
payables_and_accrued_expenses = stock.info.get("payablesAndAccruedExpenses")
payables = stock.info.get("accountsPayable")
total_tax_payable = stock.info.get("taxPayable")
current_accrued_expenses = stock.info.get("accruedExpenses")
interest_payable = stock.info.get("interestPayable")
current_provisions = stock.info.get("currentProvisions")
current_debt_and_capital_lease_obligation = stock.info.get("currentDebtAndCapitalLeaseObligation")
current_debt = stock.info.get("currentDebt")
other_current_borrowings = stock.info.get("otherCurrentBorrowings")
current_capital_lease_obligation = stock.info.get("currentCapitalLeaseObligation")
current_deferred_liabilities = stock.info.get("currentDeferredLiabilities")
current_deferred_revenue = stock.info.get("currentDeferredRevenue")
other_current_liabilities = stock.info.get("otherCurrentLiabilities")
total_non_current_liabilities_net_minority_interest = stock.info.get("totalNonCurrentLiabilitiesNetMinorityInterest")
long_term_provisions = stock.info.get("longTermProvisions")
long_term_debt_and_capital_lease_obligation = stock.info.get("longTermDebtAndCapitalLeaseObligation")
long_term_debt = stock.info.get("longTermDebt")
long_term_capital_lease_obligation = stock.info.get("longTermCapitalLeaseObligation")
non_current_deferred_liabilities = stock.info.get("nonCurrentDeferredLiabilities")
non_current_deferred_taxes_liabilities = stock.info.get("nonCurrentDeferredTaxesLiabilities")
non_current_deferred_revenue = stock.info.get("nonCurrentDeferredRevenue")
non_current_accrued_expenses = stock.info.get("nonCurrentAccruedExpenses")
preferred_securities_outside_stock_equity = stock.info.get("preferredStockOutsideStockEquity")
other_non_current_liabilities = stock.info.get("otherNonCurrentLiabilities")

# Get equity metrics
total_equity_gross_minority_interest = stock.info.get("totalStockholderEquity")
stockholders_equity = stock.info.get("totalStockholderEquity")
capital_stock = stock.info.get("commonStock")
preferred_stock = stock.info.get("preferredStock")
common_stock = stock.info.get("commonStock")
additional_paid_in_capital = stock.info.get("additionalPaidInCapital")
retained_earnings = stock.info.get("retainedEarnings")
gains_losses_not_affecting_retained_earnings = stock.info.get("earnings")
other_equity_adjustments = stock.info.get("otherEquityInterest")
minority_interest = stock.info.get("minorityInterest")

# Get capitalization metrics
total_capitalization = stock.info.get("totalCapitalization")
common_stock_equity = stock.info.get("totalStockholderEquity")
capital_lease_obligations = stock.info.get("capitalLeaseObligations")
net_tangible_assets = stock.info.get("tangibleAssets")
working_capital = stock.info.get("workingCapital")
invested_capital = stock.info.get("investedCapital")
tangible_book_value = stock.info.get("tangibleBookValue")
total_debt = stock.info.get("totalDebt")
net_debt = stock.info.get("netDebt")

# Get shares-related metrics
share_issued = stock.info.get("sharesOutstanding")
ordinary_shares_number = stock.info.get("sharesOutstanding")

# %%
# Get cash flow-related metrics
operating_cash_flow = stock.info.get("operatingCashflow")
cash_flow_from_continuing_operating_activities = stock.info.get("operatingCashflow")
net_income_from_continuing_operations = stock.info.get("netIncomeFromContinuingOps")
operating_gains_losses = stock.info.get("otherGainsLosses")
gain_loss_on_sale_of_ppe = stock.info.get("gainLossOnSaleOfAssets")
net_foreign_currency_exchange_gain_loss = stock.info.get("foreignCurrencyTransactionGainLoss")
depreciation_amortization_depletion = stock.info.get("depreciation")
depreciation = stock.info.get("depreciation")
asset_impairment_charge = stock.info.get("assetImpairmentCharge")
stock_based_compensation = stock.info.get("stockBasedCompensation")
other_non_cash_items = stock.info.get("otherNonCashItems")
change_in_working_capital = stock.info.get("changeInWorkingCapital")
change_in_receivables = stock.info.get("changesInAccountReceivables")
changes_in_account_receivables = stock.info.get("changesInAccountReceivables")
change_in_inventory = stock.info.get("changeInInventory")
change_in_prepaid_assets = stock.info.get("changeInPrepaidAssets")
change_in_payables_and_accrued_expense = stock.info.get("changesInAccountReceivables")
change_in_other_current_assets = stock.info.get("changeInOtherCurrentAssets")
change_in_other_current_liabilities = stock.info.get("changeInOtherCurrentLiabilities")
change_in_other_working_capital = stock.info.get("changeInOtherWorkingCapital")

# Get investing cash flow metrics
investing_cash_flow = stock.info.get("investingCashflow")
cash_flow_from_continuing_investing_activities = stock.info.get("investingCashflow")
capital_expenditure_reported = stock.info.get("capitalExpenditure")
net_ppe_purchase_and_sale = stock.info.get("purchaseOfBusiness")
purchase_of_ppe = stock.info.get("purchaseOfBusiness")
net_intangibles_purchase_and_sale = stock.info.get("purchaseOfIntangibles")
purchase_of_intangibles = stock.info.get("purchaseOfIntangibles")
sale_of_intangibles = stock.info.get("saleOfIntangibles")
net_business_purchase_and_sale = stock.info.get("purchaseOfInvestment")
purchase_of_business = stock.info.get("purchaseOfInvestment")
sale_of_business = stock.info.get("saleOfBusiness")
net_investment_purchase_and_sale = stock.info.get("purchaseOfInvestment")
purchase_of_investment = stock.info.get("purchaseOfInvestment")
sale_of_investment = stock.info.get("saleOfInvestment")
net_other_investing_changes = stock.info.get("purchaseOfInvestment")

# Get financing cash flow metrics
financing_cash_flow = stock.info.get("financingCashflow")
cash_flow_from_continuing_financing_activities = stock.info.get("financingCashflow")
net_issuance_payments_of_debt = stock.info.get("netIssuancePaymentsOfDebt")
net_long_term_debt_issuance = stock.info.get("netIssuancePaymentsOfDebt")
long_term_debt_issuance = stock.info.get("longTermDebtIssuance")
long_term_debt_payments = stock.info.get("longTermDebtPayments")
net_common_stock_issuance = stock.info.get("netIssuancePaymentsOfDebt")
common_stock_issuance = stock.info.get("commonStockIssuance")
proceeds_from_stock_option_exercised = stock.info.get("proceedsFromStockOptionExercised")
net_other_financing_charges = stock.info.get("netIssuancePaymentsOfDebt")

# Get cash and balance-related metrics
end_cash_position = stock.info.get("totalCash")
changes_in_cash = stock.info.get("cashflow")
effect_of_exchange_rate_changes = stock.info.get("effectOfExchangeRateChanges")
beginning_cash_position = stock.info.get("totalCashFromOperatingActivities")
income_tax_paid_supplemental_data = stock.info.get("incomeTaxPaidSupplementalData")
interest_paid_supplemental_data = stock.info.get("interestPaidSupplementalData")
capital_expenditure = stock.info.get("capitalExpenditure")
issuance_of_capital_stock = stock.info.get("issuanceOfCapitalStock")
issuance_of_debt = stock.info.get("issuanceOfDebt")
repayment_of_debt = stock.info.get("repaymentOfDebt")
free_cash_flow = operating_cash_flow - capital_expenditure

# %%
# Upload to S3
s3 = boto3.client(
    's3',
    aws_access_key_id="YOUR_ACCESS_KEY",
    aws_secret_access_key="YOUR_SECRET_KEY",
    region_name="YOUR_AWS_REGION"
)

bucket_name = 'your-s3-bucket-name'  # Replace with your S3 bucket name
object_name = 'path/to/your/table.csv'  # Replace with the desired path and object name

try:
    # Load your DataFrame or table into a variable 'df' (this is a sample DataFrame)
    # Replace 'df' with the DataFrame or table you want to upload
    df = news_df

    # Convert the DataFrame to CSV format
    csv_news_df = df.to_csv(index=False)

    # Upload the CSV data to S3
    s3.put_object(Bucket=bucket_name, Key=object_name, Body=csv_news_df)

    print(f'Table uploaded to S3 bucket: {bucket_name}, object: {object_name}')
except NoCredentialsError:
    print("AWS credentials not available.")
# Out:
# ---------------------------------------------------------------------------
# InvalidRegionError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6724\193779264.py in <module>
#       1 # Upload to S3
# ----> 2 s3 = boto3.client(
#       3     's3',
#       4     aws_access_key_id="YOUR_ACCESS_KEY",
#       5     aws_secret_access_key="YOUR_SECRET_KEY",
#
# c:\Users\Arun Anpalagan\Anaconda\envs\quant\lib\site-packages\boto3\__init__.py in client(*args, **kwargs)
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#      93
#      94
#
# c:\Users\Arun Anpalagan\Anaconda\envs\quant\lib\site-packages\boto3\session.py in client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     297
#     298         """
# --> 299         return self._session.create_client(
# ...

# %%
session = boto3.Session(
    aws_access_key_id="YOUR_ACCESS_KEY",
    aws_secret_access_key="YOUR_SECRET_KEY",
    region_name="YOUR_AWS_REGION"
)

# Create an S3 client
s3 = session.client('s3')

# Define the S3 bucket and object (the path to your table)
bucket_name = 'your-s3-bucket-name'
object_name = 'path/to/your/table.csv'

# Use S3 client to get the object (table) from S3
response = s3.get_object(Bucket=bucket_name, Key=object_name)
table_data = response['Body'].read().decode('utf-8')

# Use Pandas to read the table data
df = pd.read_csv(pd.compat.StringIO(table_data))

# Now, you have your table in the DataFrame 'df'

# %%
# Post
